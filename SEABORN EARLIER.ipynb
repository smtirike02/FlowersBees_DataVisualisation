# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from svgpathtools import svg2paths
from svgpath2mpl import parse_path

# %%
# Apply the default theme
sns.set_theme()

# %%
data = pd.read_csv("flowerdatafinal1.csv") #counts data and output the amount its been mentioned

# %%
from collections import Counter

flowers = ['Common Bird\'s-foot-trefoil',
    'Lesser Stitchwort',
    'Scarlet Pimpernel',
    'White Clover',
    'Creeping Buttercup',
    'Common Bird\'s-foot-trefoil',
    'White Clover',
    'Curled Dock',
    'Common Vetch',
    'Hemlock Water-dropwort',
    'Creeping Buttercup',
    'Greater Bird\'s-foot-trefoil',
    'Creeping Buttercup',
    'Creeping Buttercup',
    'Common Chickweed',
    'Curled Dock',
    'Meadow Buttercup',
    'Meadow Buttercup',
    'White Clover',
    'Red Clover',
    'Common Sorrel',
    'White Clover',
    'White Clover',
    'Ribwort Plantain',
    'Meadow Buttercup',
    'Ribwort Plantain',
    'Rough Hawkbit',
    'Creeping Buttercup',
    'Creeping Buttercup',
    'Tormentil',
    'Creeping Buttercup',
    'Creeping Buttercup',
    'Marsh Thistle',
    'White Clover',
    'White Clover',
    'Cleavers',
    'Red Clover',
    'Red Clover',
    'Cat\'s-ear',
    'Red Clover',
    'Common Nettle',
    'Common Bird\'s-foot-trefoil',
    'Meadow Buttercup',
    'Lesser Stitchwort',
    'Common Bird\'s-foot-trefoil',
    'Lesser Stitchwort'
    ]

# %%
Counter(flowers)
# Out:
# Counter({"Common Bird's-foot-trefoil": 4,
#          'Lesser Stitchwort': 3,
#          'Scarlet Pimpernel': 1,
#          'White Clover': 7,
#          'Creeping Buttercup': 8,
#          'Curled Dock': 2,
#          'Common Vetch': 1,
#          'Hemlock Water-dropwort': 1,
#          "Greater Bird's-foot-trefoil": 1,
#          'Common Chickweed': 1,
#          'Meadow Buttercup': 4,
#          'Red Clover': 4,
#          'Common Sorrel': 1,
#          'Ribwort Plantain': 2,
#          'Rough Hawkbit': 1,
#          'Tormentil': 1,
#          'Marsh Thistle': 1,
#          'Cleavers': 1,
#          "Cat's-ear": 1,
#          'Common Nettle': 1})

# %%
sns.scatterplot(data=data, x="floral_unit", y="total_floral_units",size = "total_floral_units",hue="English_name",
alpha=0.5, sizes=(200,450),marker = ([8, 1, 3]),)#,palette = "Pastel2")
#ax.set_frame_on(False)



plt.legend(loc='upper left',  bbox_to_anchor=(2, 1),fontsize='10') #info on the left 
sns.despine(bottom=True) #remove borders
#sns.despine(left=True)
#ax.tick_params(bottom=False)

sns.set(font_scale=8)
sns.set(rc={"figure.figsize":(10, 5)}) #(w,h)
sns.set_theme(style="white")

# %%
sns.color_palette("Set2")
# Out:
# [(0.4, 0.7607843137254902, 0.6470588235294118),
#  (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
#  (0.5529411764705883, 0.6274509803921569, 0.796078431372549),
#  (0.9058823529411765, 0.5411764705882353, 0.7647058823529411),
#  (0.6509803921568628, 0.8470588235294118, 0.32941176470588235),
#  (1.0, 0.8509803921568627, 0.1843137254901961),
#  (0.8980392156862745, 0.7686274509803922, 0.5803921568627451),
#  (0.7019607843137254, 0.7019607843137254, 0.7019607843137254)]

# %%
sns.color_palette("husl", 8)
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.8087954113106306, 0.5634700050056693, 0.19502642696727285),
#  (0.5920891529639701, 0.6418467016378244, 0.1935069134991043),
#  (0.19783576093349015, 0.6955516966063037, 0.3995301037444499),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681),
#  (0.22335772267769388, 0.6565792317435265, 0.8171355503265633),
#  (0.6423044349219739, 0.5497680051256467, 0.9582651433656727),
#  (0.9603888539940703, 0.3814317878772117, 0.8683117650835491)]

# %%
import circlify
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import svgwrite

# %%
data1 = pd.read_csv("flowerdatafinal1.csv")

# %%
data1
# Out:
#     country                 English_name        floral_unit  \
# 0   England   Common Bird's-foot-trefoil        flower head
# 1   England            Lesser Stitchwort  individual flower
# 2   England            Scarlet Pimpernel  individual flower
# 3   England                 White Clover        flower head
# 4   England           Creeping Buttercup  individual flower
# 5   England   Common Bird's-foot-trefoil        flower head
# 6   England                 White Clover        flower head
# 7   England                  Curled Dock       flower spike
# 8   England                 Common Vetch  individual flower
# 9   England       Hemlock Water-dropwort       flower umbel
# 10  England           Creeping Buttercup  individual flower
# 11  England  Greater Bird's-foot-trefoil        flower head
# 12  England           Creeping Buttercup  individual flower
# 13  England           Creeping Buttercup  individual flower
# 14  England             Common Chickweed  individual flower
# ...

# %%
from matplotlib import pyplot as plt
from matplotlib.patches import FancyBboxPatch
from matplotlib.path import get_path_collection_extents

# size of graph
plt.figure(figsize=(20,20))

# plot polar axis
ax = plt.subplot(111, polar=True)

# remove grid
plt.axis('off')

# coordinates limit
upperLimit = 100
lowerLimit = 30

max = data1['total_floral_units'].max()


fig.patch.set_facecolor("white")

def add_fancy_patch_around(ax, bb, **kwargs):
    fancy = FancyBboxPatch(bb.p0, bb.width, bb.height,
                           fc=(1, 0.8, 1, 0.5), ec=(1, 0.5, 1, 0.5),
                           **kwargs)


slope = (max - lowerLimit) / max
heights = slope *data1.total_floral_units 

width = 2*np.pi / len(data1.index)

indexes = list(range(1, len(data1.index)+1))
angles = [element * width for element in indexes]
angles


bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=3, 
    edgecolor="pink" , 
    
    facecolor="none")


#padding to give space
labelPadding = 25



for bar, angle, height, label in zip(bars,angles, heights, data1["English_name"]): # add labels

    
    rotation = np.rad2deg(angle)

    # upside down labels
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 10
    else: 
        alignment = "left"

    #labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
)
