# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot, savefig

# %%
data4 =  pd.read_csv('bees_total_count_and_flowers_with_years.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None) # to display all coloumns and rows
data4[:640]
# Out:
#      country  year  floral_unit_count  bumblebees  honeybees  solitary_bees  \
# 0    England  2017                 24           3          2              0
# 1    England  2017                  7           0          0              1
# 2    England  2017                 85           1          0              1
# 3    England  2017                 15           0          0              1
# 4    England  2017                 80           2          0              0
# 5    England  2017                 43           0          0              0
# 6    England  2017                 11           1          0              1
# 7    England  2017                  8           0          0              0
# 8    England  2017                 28           0          0              0
# 9    England  2017                 29           0          0              0
# 10   England  2017                  7           0          0              0
# ...

# %%
bubbledata = pd.read_csv("flowerdatafinal1.csv")

# %%
circles = circlify.circlify(
    bubbledata['total_floral_units'].tolist(), 
    show_enclosure=False, 
    target_enclosure=circlify.Circle(x=0, y=0, r=1)
)



fig, ax = plt.subplots(figsize=(10,10)) #adjust size
labels = bubbledata['total_floral_units']  #label


ax.axis('off') #to remove axis




# creates an axis boundary
lim = max(
    max(
        abs(circle.x) + circle.r,
        abs(circle.y) + circle.r,
    )
    for circle in circles
)
plt.xlim(-lim, lim)
plt.ylim(-lim, lim)

# title
ax.set_title('Floral Density in England')


# print the circles
for circle, label in zip(circles, labels):
    x, y, r = circle
    ax.add_patch(plt.Circle((x, y), r, alpha=0.2, linewidth=2))
    plt.annotate(label, (x,y ) ,va='center', ha='center')

# %%
sns.relplot(
    data=data4,
    x="floral_unit_count", y="bees_total", hue="year" #scatterplot , different hues show different years
)

# %%
data =  pd.read_csv('bees_total_count_and_flowers_with_years.csv')

sns.barplot(data=data, x="year", y="floral_unit_count", palette = "RdPu",errorbar=None).set(title='Flower Density in England during 2017-2020')
sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)

plt.xlabel('Year')
plt.ylabel('Flower Density')
# Out:
# Text(0, 0.5, 'Flower Density')

# %%
data =  pd.read_csv('bees_total_count_and_flowers_with_years.csv')

sns.barplot(data=data, x="year", y="bees_total", palette = "YlOrBr",errorbar=None).set(title='Bee density in England during 2017-2020')
sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False) #get rid of spines

plt.xlabel('Year')
plt.ylabel('Bee Density')
# Out:
# Text(0, 0.5, 'Bee Density')

# %%
import seaborn as sns
df =  pd.read_csv('bees_total_count_and_flowers_with_years.csv')

# plot
sns.violinplot(x=df["year"], y=df["bees_total"], palette = 'Wistia',linewidth=0, alpha = 0.7).set(title='Bee population in England during 2017-2020')
sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False) #line width get rid of the strokes in the middle.

plt.xlabel('Year')
plt.ylabel('no. of bees recorded per 10 minutes')
# Out:
# Text(0, 0.5, 'no. of bees recorded per 10 minutes')

# %%
import seaborn as sns
df =  pd.read_csv('bees_total_count_and_flowers_with_years.csv') 


sns.violinplot(x=df["year"], y=df["floral_unit_count"], palette = 'RdPu',linewidth=0.25, alpha = 0.7).set(title='Flower Density in England during 2017-2020')
sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False) 



plt.xlabel('Year')
plt.ylabel('no. of floral units in the 50×50 cm patch')
# Out:
# Text(0, 0.5, 'no. of floral units in the 50×50 cm patch')

# %%
import seaborn as sns
sns.set_theme(style="white") #changes background


data = pd.read_csv('bees_total_count_and_flowers_with_years.csv')

sns.relplot(x="bees_total", y="floral_unit_count",size = "year",hue= 'year',
            sizes=(50, 400), alpha=.5, palette="Set2",
            height=10, data=data) #alpha= transparency

# %%
data1 = pd.read_csv('bees_total_count_and_flowers_with_years.csv')
sns.set_style("white")
sns.kdeplot(data=data1, x="bees_total",hue="year",multiple="stack" , linewidth=1, palette = 'Wistia_r').set(title='Bee Population in England during 2017-2020')
sns.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)
plt.xlabel('No. of bees every 10 minutes recorded') #multiple style: stack,fill

# %%
data1 = pd.read_csv('bees_total_count_and_flowers_with_years.csv')
fig, ax = plt.subplots()
sns.set_style("white")
sns.kdeplot(data=data1,ax=ax,x="floral_unit_count",hue="year",multiple="stack",palette = 'PuRd_r').set(title='Flower desity in England during 2017-2020')
sns.despine(fig=None,  top=True, right=True, left=False, bottom=False, offset=None, trim=False)

plt.xlabel('No. of floral units in the 50×50 cm patch')
# Out:
# Text(0.5, 0, 'No. of floral units in the 50×50 cm patch')

# %%
data =  pd.read_csv('bees_total_count_and_flowers_with_years.csv')



g = sns.FacetGrid(data,  col="year",hue = "year", palette="PuRd", despine=True)
g.map(sns.scatterplot, "bees_total", "floral_unit_count")   #g.map declares the type of plot im using
#col = column that shows the year of the decline

# %%
data =  pd.read_csv('bees_total_count_and_flowers_with_years.csv')


#facet 
g = sns.FacetGrid(data,  row="year",hue = "year", palette="RdPu", despine=False)
g.map(sns.scatterplot, "bees_total", "floral_unit_count")  #g.map declares the type of plot im using

# %%
sns.color_palette("YlOrBr", 4)
# Out:
# [(0.9976470588235294, 0.9215686274509803, 0.636078431372549),
#  (0.996078431372549, 0.7349019607843138, 0.28),
#  (0.939607843137255, 0.4713725490196078, 0.09490196078431372),
#  (0.72, 0.2603921568627451, 0.010980392156862745)]

# %%
sns.color_palette("RdPu", 4)
# Out:
# [(0.9898039215686275, 0.8149019607843138, 0.7984313725490196),
#  (0.9780392156862745, 0.5803921568627451, 0.6941176470588235),
#  (0.8870588235294118, 0.24470588235294116, 0.6),
#  (0.6007843137254902, 0.00392156862745098, 0.4831372549019608)]

# %%
sns.color_palette("PuRd", 4)
# Out:
# [(0.8611764705882353, 0.788235294117647, 0.8878431372549019),
#  (0.8054901960784313, 0.5435294117647059, 0.7623529411764706),
#  (0.899607843137255, 0.20784313725490194, 0.5709803921568627),
#  (0.7231372549019608, 0.042352941176470586, 0.3074509803921569)]
