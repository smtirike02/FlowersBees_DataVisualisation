# %%
import pandas as pd

# %%
spreadsheet = pd.read_csv('ukpoms_1kmpantrapdata_2017-2020_flowers.csv')[:60]

# %%
spreadsheet
# Out:
#     sample_id  country  location_code       location_name X1km_square  \
# 0     3054144  England             76  near West Itchenor      SU7800
# 1     3054249  England             76  near West Itchenor      SU7800
# 2     3054249  England             76  near West Itchenor      SU7800
# 3     3054249  England             76  near West Itchenor      SU7800
# 4     3054249  England             76  near West Itchenor      SU7800
# 5     3054249  England             76  near West Itchenor      SU7800
# 6     3054547  England             76  near West Itchenor      SU7800
# 7     3054547  England             76  near West Itchenor      SU7800
# 8     3054547  England             76  near West Itchenor      SU7800
# 9     3054547  England             76  near West Itchenor      SU7800
# 10    3054564  England             76  near West Itchenor      SU7800
# 11    3054564  England             76  near West Itchenor      SU7800
# ...

# %%
spreadsheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   sample_id                 60 non-null     int64
#  1   country                   60 non-null     object
#  2   location_code             60 non-null     int64
#  3   location_name             60 non-null     object
#  4   X1km_square               60 non-null     object
#  5   date                      60 non-null     object
#  6   year                      60 non-null     int64
#  7   pan_trap_station          60 non-null     int64
#  8   occurrence_id             60 non-null     int64
#  9   taxon_group               60 non-null     object
#  10  taxon_source              60 non-null     object
#  11  English_name              60 non-null     object
#  12  source_taxon_version_key  60 non-null     object
#  13  Order                     60 non-null     object
# ...

# %%
spreadsheet.dtypes #shows the types of data
# Out:
# sample_id                     int64
# country                      object
# location_code                 int64
# location_name                object
# X1km_square                  object
# date                         object
# year                          int64
# pan_trap_station              int64
# occurrence_id                 int64
# taxon_group                  object
# taxon_source                 object
# English_name                 object
# source_taxon_version_key     object
# Order                        object
# Family                       object
# floral_unit                  object
# total_floral_units          float64
# dtype: object

# %%
spreadsheet.head(100)[['date','country','English_name','total_floral_units']]
# Out:
#           date  country                 English_name  total_floral_units
# 0   16/06/2017  England           Creeping Buttercup                 3.0
# 1   16/06/2017  England           Creeping Buttercup                 6.0
# 2   16/06/2017  England            Lesser Stitchwort               160.0
# 3   16/06/2017  England  Greater Bird's-foot-trefoil                 6.0
# 4   16/06/2017  England                 Common Vetch                 4.0
# 5   16/06/2017  England       Hemlock Water-dropwort                 4.0
# 6   16/06/2017  England           Creeping Buttercup                 6.0
# 7   16/06/2017  England             Common Chickweed                 6.0
# 8   16/06/2017  England                  Curled Dock                 4.0
# 9   16/06/2017  England            Scarlet Pimpernel                 2.0
# 10  16/06/2017  England                  Curled Dock                 8.0
# 11  16/06/2017  England                     Cleavers                40.0
# ...

# %%
spreadsheet.sort_values(by=['country','total_floral_units'],ascending=True)[:60] #sees maximum that data allows
# Out:
#     sample_id  country  location_code       location_name X1km_square  \
# 43    3070340  England              5       near Longtown      SO3129
# 9     3054547  England             76  near West Itchenor      SU7800
# 24    3066030  England             96          LLanrothal      SO4718
# 27    3066048  England             96          LLanrothal      SO4718
# 0     3054144  England             76  near West Itchenor      SU7800
# 28    3066048  England             96          LLanrothal      SO4718
# 41    3070340  England              5       near Longtown      SO3129
# 4     3054249  England             76  near West Itchenor      SU7800
# 5     3054249  England             76  near West Itchenor      SU7800
# 8     3054547  England             76  near West Itchenor      SU7800
# 1     3054249  England             76  near West Itchenor      SU7800
# 3     3054249  England             76  near West Itchenor      SU7800
# ...

# %%
print(pd.options.display.max_rows) #shows max rows
# Out:
# 60

# %%
spreadsheet.to_csv('TFUdata.csv', index=False)

# %%
spreadsheet1 = pd.read_csv('TFUdata.csv')[:60]

# %%
spreadsheet1
# Out:
#     sample_id  country  location_code       location_name X1km_square  \
# 0     3054144  England             76  near West Itchenor      SU7800
# 1     3054249  England             76  near West Itchenor      SU7800
# 2     3054249  England             76  near West Itchenor      SU7800
# 3     3054249  England             76  near West Itchenor      SU7800
# 4     3054249  England             76  near West Itchenor      SU7800
# 5     3054249  England             76  near West Itchenor      SU7800
# 6     3054547  England             76  near West Itchenor      SU7800
# 7     3054547  England             76  near West Itchenor      SU7800
# 8     3054547  England             76  near West Itchenor      SU7800
# 9     3054547  England             76  near West Itchenor      SU7800
# 10    3054564  England             76  near West Itchenor      SU7800
# 11    3054564  England             76  near West Itchenor      SU7800
# ...

# %%
spreadsheet.sort_values(by=['country','total_floral_units'],ascending=True)[:60]
# Out:
#     sample_id  country  location_code       location_name X1km_square  \
# 43    3070340  England              5       near Longtown      SO3129
# 9     3054547  England             76  near West Itchenor      SU7800
# 24    3066030  England             96          LLanrothal      SO4718
# 27    3066048  England             96          LLanrothal      SO4718
# 0     3054144  England             76  near West Itchenor      SU7800
# 28    3066048  England             96          LLanrothal      SO4718
# 41    3070340  England              5       near Longtown      SO3129
# 4     3054249  England             76  near West Itchenor      SU7800
# 5     3054249  England             76  near West Itchenor      SU7800
# 8     3054547  England             76  near West Itchenor      SU7800
# 1     3054249  England             76  near West Itchenor      SU7800
# 3     3054249  England             76  near West Itchenor      SU7800
# ...

# %%
spreadsheet = spreadsheet.drop(spreadsheet.index[-1])

# %%
spreadsheet
# Out:
#     sample_id  country  location_code       location_name X1km_square  \
# 0     3054144  England             76  near West Itchenor      SU7800
# 1     3054249  England             76  near West Itchenor      SU7800
# 2     3054249  England             76  near West Itchenor      SU7800
# 3     3054249  England             76  near West Itchenor      SU7800
# 4     3054249  England             76  near West Itchenor      SU7800
# 5     3054249  England             76  near West Itchenor      SU7800
# 6     3054547  England             76  near West Itchenor      SU7800
# 7     3054547  England             76  near West Itchenor      SU7800
# 8     3054547  England             76  near West Itchenor      SU7800
# 9     3054547  England             76  near West Itchenor      SU7800
# 10    3054564  England             76  near West Itchenor      SU7800
# 11    3054564  England             76  near West Itchenor      SU7800
# ...

# %%
spreadsheet.to_csv('TFUdata1.csv', index=False)

# %%
spreadsheet.head(100)[['country','English_name','total_floral_units']]
# Out:
#     country                 English_name  total_floral_units
# 0   England           Creeping Buttercup                 3.0
# 1   England           Creeping Buttercup                 6.0
# 2   England            Lesser Stitchwort               160.0
# 3   England  Greater Bird's-foot-trefoil                 6.0
# 4   England                 Common Vetch                 4.0
# 5   England       Hemlock Water-dropwort                 4.0
# 6   England           Creeping Buttercup                 6.0
# 7   England             Common Chickweed                 6.0
# 8   England                  Curled Dock                 4.0
# 9   England            Scarlet Pimpernel                 2.0
# 10  England                  Curled Dock                 8.0
# 11  England                     Cleavers                40.0
# 12  England                Common Nettle                60.0
# 13  England           Creeping Buttercup                17.0
# ...

# %%
spreadsheet.drop(['sample_id','location_code','location_name','X1km_square','date','year','pan_trap_station','occurrence_id','taxon_group','taxon_source','source_taxon_version_key','Order','Family'], axis=1)
# Out:
#     country                 English_name        floral_unit  \
# 0   England           Creeping Buttercup  individual flower
# 1   England           Creeping Buttercup  individual flower
# 2   England            Lesser Stitchwort  individual flower
# 3   England  Greater Bird's-foot-trefoil        flower head
# 4   England                 Common Vetch  individual flower
# 5   England       Hemlock Water-dropwort       flower umbel
# 6   England           Creeping Buttercup  individual flower
# 7   England             Common Chickweed  individual flower
# 8   England                  Curled Dock       flower spike
# 9   England            Scarlet Pimpernel  individual flower
# 10  England                  Curled Dock       flower spike
# 11  England                     Cleavers  individual flower
# 12  England                Common Nettle       flower spike
# 13  England           Creeping Buttercup  individual flower
# 14  England                   Red Clover        flower head
# ...

# %%
spreadsheet.drop(spreadsheet[spreadsheet['country'] == 'Wales'].index,inplace = True) #drop country wales

# %%
spreadsheet
# Out:
#     sample_id  country  location_code       location_name X1km_square  \
# 0     3054144  England             76  near West Itchenor      SU7800
# 1     3054249  England             76  near West Itchenor      SU7800
# 2     3054249  England             76  near West Itchenor      SU7800
# 3     3054249  England             76  near West Itchenor      SU7800
# 4     3054249  England             76  near West Itchenor      SU7800
# 5     3054249  England             76  near West Itchenor      SU7800
# 6     3054547  England             76  near West Itchenor      SU7800
# 7     3054547  England             76  near West Itchenor      SU7800
# 8     3054547  England             76  near West Itchenor      SU7800
# 9     3054547  England             76  near West Itchenor      SU7800
# 10    3054564  England             76  near West Itchenor      SU7800
# 11    3054564  England             76  near West Itchenor      SU7800
# ...

# %%
spreadsheet.to_csv('EngFlower.csv', index=False)

# %%
spreadsheet.drop(['sample_id','location_code','location_name','X1km_square','date','year','pan_trap_station','occurrence_id','taxon_group','taxon_source','source_taxon_version_key','Order','Family'], axis=1)
# Out:
#     country                 English_name        floral_unit  \
# 0   England           Creeping Buttercup  individual flower
# 1   England           Creeping Buttercup  individual flower
# 2   England            Lesser Stitchwort  individual flower
# 3   England  Greater Bird's-foot-trefoil        flower head
# 4   England                 Common Vetch  individual flower
# 5   England       Hemlock Water-dropwort       flower umbel
# 6   England           Creeping Buttercup  individual flower
# 7   England             Common Chickweed  individual flower
# 8   England                  Curled Dock       flower spike
# 9   England            Scarlet Pimpernel  individual flower
# 10  England                  Curled Dock       flower spike
# 11  England                     Cleavers  individual flower
# 12  England                Common Nettle       flower spike
# 13  England           Creeping Buttercup  individual flower
# 14  England                   Red Clover        flower head
# ...

# %%
spreadsheet.to_csv('EngFlower.csv', index=False)

# %%
spreadsheet2= pd.read_csv('EngFlower.csv')[:60]

# %%
spreadsheet2
# Out:
#     sample_id  country  location_code       location_name X1km_square  \
# 0     3054144  England             76  near West Itchenor      SU7800
# 1     3054249  England             76  near West Itchenor      SU7800
# 2     3054249  England             76  near West Itchenor      SU7800
# 3     3054249  England             76  near West Itchenor      SU7800
# 4     3054249  England             76  near West Itchenor      SU7800
# 5     3054249  England             76  near West Itchenor      SU7800
# 6     3054547  England             76  near West Itchenor      SU7800
# 7     3054547  England             76  near West Itchenor      SU7800
# 8     3054547  England             76  near West Itchenor      SU7800
# 9     3054547  England             76  near West Itchenor      SU7800
# 10    3054564  England             76  near West Itchenor      SU7800
# 11    3054564  England             76  near West Itchenor      SU7800
# ...

# %%
spreadsheet2.drop(['sample_id','location_code','location_name','X1km_square','date','year','pan_trap_station','occurrence_id','taxon_group','taxon_source','source_taxon_version_key','Order','Family'], axis=1)
# Out:
#     country                 English_name        floral_unit  \
# 0   England           Creeping Buttercup  individual flower
# 1   England           Creeping Buttercup  individual flower
# 2   England            Lesser Stitchwort  individual flower
# 3   England  Greater Bird's-foot-trefoil        flower head
# 4   England                 Common Vetch  individual flower
# 5   England       Hemlock Water-dropwort       flower umbel
# 6   England           Creeping Buttercup  individual flower
# 7   England             Common Chickweed  individual flower
# 8   England                  Curled Dock       flower spike
# 9   England            Scarlet Pimpernel  individual flower
# 10  England                  Curled Dock       flower spike
# 11  England                     Cleavers  individual flower
# 12  England                Common Nettle       flower spike
# 13  England           Creeping Buttercup  individual flower
# 14  England                   Red Clover        flower head
# ...

# %%
spreadsheet3 = spreadsheet2.drop(['sample_id','location_code','location_name','X1km_square','date','year','pan_trap_station','occurrence_id','taxon_group','taxon_source','source_taxon_version_key','Order','Family'], axis=1)

# %%
spreadsheet3.to_csv('flowerdatafinal.csv', index=False)

# %%
spreadsheet3.sort_values(by=['total_floral_units'],ascending=True)[:60]  #total floral units low to high
# Out:
#     country                 English_name        floral_unit  \
# 36  England   Common Bird's-foot-trefoil        flower head
# 27  England            Lesser Stitchwort  individual flower
# 9   England            Scarlet Pimpernel  individual flower
# 24  England                 White Clover        flower head
# 0   England           Creeping Buttercup  individual flower
# 28  England   Common Bird's-foot-trefoil        flower head
# 34  England                 White Clover        flower head
# 8   England                  Curled Dock       flower spike
# 4   England                 Common Vetch  individual flower
# 5   England       Hemlock Water-dropwort       flower umbel
# 6   England           Creeping Buttercup  individual flower
# 3   England  Greater Bird's-foot-trefoil        flower head
# 33  England           Creeping Buttercup  individual flower
# 1   England           Creeping Buttercup  individual flower
# 7   England             Common Chickweed  individual flower
# ...

# %%
spreadsheet4 = spreadsheet3.sort_values(by=['total_floral_units'],ascending=True)[:60]

# %%
spreadsheet4
# Out:
#     country                 English_name        floral_unit  \
# 36  England   Common Bird's-foot-trefoil        flower head
# 27  England            Lesser Stitchwort  individual flower
# 9   England            Scarlet Pimpernel  individual flower
# 24  England                 White Clover        flower head
# 0   England           Creeping Buttercup  individual flower
# 28  England   Common Bird's-foot-trefoil        flower head
# 34  England                 White Clover        flower head
# 8   England                  Curled Dock       flower spike
# 4   England                 Common Vetch  individual flower
# 5   England       Hemlock Water-dropwort       flower umbel
# 6   England           Creeping Buttercup  individual flower
# 3   England  Greater Bird's-foot-trefoil        flower head
# 33  England           Creeping Buttercup  individual flower
# 1   England           Creeping Buttercup  individual flower
# 7   England             Common Chickweed  individual flower
# ...

# %%
spreadsheet4.to_csv('flowerdatafinal1.csv', index=False)
